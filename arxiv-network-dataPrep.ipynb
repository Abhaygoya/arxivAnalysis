# %% [markdown]
# ## Data import and prep
#
# This loads arxiv data and preps a dataframe for analysis by arxiv-network-analysis.ipynb

# %%
import pandas as pd 
import numpy as np 
from datetime import datetime

import json
import dask.bag as db

from itertools import combinations

# %%
category_list=['cond-mat'] ## Condense matter physics
records=db.read_text("data/arxiv-metadata-oai-snapshot.json").map(lambda x:json.loads(x))
docs = (records.filter(lambda x:any(ele in x['categories'] for ele in category_list)==True))
get_metadata = lambda x: {'id': x['id'],
                  'title': x['title'],
                  'category':x['categories'],
                  'abstract':x['abstract'],
                 'version':x['versions'][-1]['created'],
                         'doi':x["doi"],
                         'authors_parsed':x['authors_parsed']}

data=docs.map(get_metadata).to_dataframe().compute()

# %%
# Concatenate the author first and last names
data['num_authors']=data['authors_parsed'].apply(lambda x:len(x))

data['authors']=data['authors_parsed'].apply(lambda authors:[(" ".join(author)).strip() for author in authors])
data.head()
# Out:
#           id                                              title  \
# 0  0704.0006  Bosonic characters of atomic Cooper pairs acro...
# 1  0704.0008  Numerical solution of shock and ramp compressi...
# 2  0704.0025  Spectroscopic Properties of Polarons in Strong...
# 3  0704.0027  Filling-Factor-Dependent Magnetophonon Resonan...
# 4  0704.0030  Tuning correlation effects with electron-phono...
#
#                              category  \
# 0                   cond-mat.mes-hall
# 1                   cond-mat.mtrl-sci
# 2  cond-mat.str-el cond-mat.stat-mech
# 3                   cond-mat.mes-hall
# 4                     cond-mat.str-el
#
#                                             abstract  \
# 0    We study the two-particle wave function of p...
# 1    A general formulation was developed to repre...
# 2    We present recent advances in understanding ...
# 3    We describe a peculiar fine structure acquir...
# 4    We investigate the effect of tuning the phon...
#
#                          version                            doi  \
# 0  Sat, 31 Mar 2007 04:24:59 GMT     10.1103/PhysRevA.75.043613
# 1   Tue, 1 Jul 2008 18:54:28 GMT              10.1063/1.2975338
# 2   Mon, 2 Apr 2007 12:02:36 GMT   10.1007/978-1-4020-6348-0_12
# 3  Thu, 24 Sep 2009 12:40:18 GMT  10.1103/PhysRevLett.99.087402
# 4  Sat, 31 Mar 2007 14:14:18 GMT      10.1007/s10909-005-6013-6
#
#                                       authors_parsed  num_authors  \
# 0                  [[Pong, Y. H., ], [Law, C. K., ]]            2
# 1                             [[Swift, Damian C., ]]            1
# 2  [[Mishchenko, A. S., , 1 and 2], [Nagaosa, N.,...            2
# 3  [[Goerbig, M. O., ], [Fuchs, J. -N., ], [Keche...            4
# 4           [[Hague, J. P., ], [d'Ambrumenil, N., ]]            2
#
#                                              authors
# 0                            [Pong Y. H., Law C. K.]
# 1                                  [Swift Damian C.]
# 2   [Mishchenko A. S.  1 and 2, Nagaosa N.  1 and 3]
# 3  [Goerbig M. O., Fuchs J. -N., Kechedzhi K., Fa...
# 4                     [Hague J. P., d'Ambrumenil N.]

# %%
data['DateTime']=pd.to_datetime(data['version'])
data['Day'] = data['DateTime'].dt.day
data['Month'] = data['DateTime'].dt.month
data['Year'] = data['DateTime'].dt.year

# %%
# Filter data (2020 to 2021)

data = data[data['Year'].between(2020, 2021)]

# %%
data['author_pairs']=data['authors'].apply(lambda x:list(combinations(x, 2)))
data.head()
# Out:
#               id                                              title  \
# 4021   0708.2697  Epsilon Expansion for Multicritical Fixed Poin...
# 5434   0710.1214  Shot-noise of quantum chaotic systems in the c...
# 6316   0711.0637  Symmetry breaking and quantum correlations in ...
# 7807   0712.4280  Dynamics of emergent Cooper pairing at finite ...
# 13137  0806.3953  Short-distance thermal correlations in the XXZ...
#
#                                                 category  \
# 4021                               hep-th cond-mat.other
# 5434                           cond-mat.mes-hall nlin.CD
# 6316   cond-mat.mes-hall cond-mat.str-el nucl-th phys...
# 7807                 cond-mat.supr-con cond-mat.mes-hall
# 13137          cond-mat.str-el cond-mat.stat-mech hep-th
#
#                                                 abstract  \
# 4021     The Polchinski version of the exact renormal...
# 5434     Semiclassical methods can now explain many m...
# 6316     Investigations of emergent symmetry breaking...
# 7807     We study the time evolution of a system of f...
# 13137    Recent studies have revealed much of the mat...
#
#                              version                               doi  \
# 4021   Fri, 29 May 2020 14:30:46 GMT         10.1016/j.aop.2007.10.005
# 5434   Fri, 18 Dec 2020 13:17:37 GMT                 10.1117/12.724670
# 6316   Wed, 22 Dec 2021 21:51:53 GMT       10.1088/0034-4885/70/12/R02
# 7807   Sun, 18 Jul 2021 04:02:26 GMT        10.1103/PhysRevB.79.132504
# 13137  Mon, 29 Nov 2021 15:11:59 GMT  10.1088/1742-5468/2008/08/P08010
#
#                                           authors_parsed  num_authors  \
# 4021                   [[O'Dwyer, J., ], [Osborn, H., ]]            2
# 5434                            [[Whitney, Robert S., ]]            1
# 6316     [[Yannouleas, Constantine, ], [Landman, Uzi, ]]            2
# 7807   [[Yuzbashyan, Emil A., ], [Tsyplyatyev, Oleksa...            2
# 13137  [[Boos, Herman E., ], [Damerau, Jens, ], [Göhm...            6
#
#                                                  authors  \
# 4021                             [O'Dwyer J., Osborn H.]
# 5434                                 [Whitney Robert S.]
# 6316               [Yannouleas Constantine, Landman Uzi]
# 7807         [Yuzbashyan Emil A., Tsyplyatyev Oleksandr]
# 13137  [Boos Herman E., Damerau Jens, Göhmann Frank, ...
#
#                        DateTime  Day  Month  Year  \
# 4021  2020-05-29 14:30:46+00:00   29      5  2020
# 5434  2020-12-18 13:17:37+00:00   18     12  2020
# 6316  2021-12-22 21:51:53+00:00   22     12  2021
# 7807  2021-07-18 04:02:26+00:00   18      7  2021
# 13137 2021-11-29 15:11:59+00:00   29     11  2021
#
#                                             author_pairs
# 4021                           [(O'Dwyer J., Osborn H.)]
# 5434                                                  []
# 6316             [(Yannouleas Constantine, Landman Uzi)]
# 7807       [(Yuzbashyan Emil A., Tsyplyatyev Oleksandr)]
# 13137  [(Boos Herman E., Damerau Jens), (Boos Herman ...

# %%
data.to_pickle('data/cond-mat-2020-2021.pkl')
